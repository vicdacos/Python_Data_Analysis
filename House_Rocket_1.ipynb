# %% [markdown]
# # 1. FONTE DE ESTUDOS
# ### Vídeo do mestre MEIGARON: https://www.youtube.com/watch?v=1xXK_z9M6yk
# ### Dados: Kaggle

# %% [markdown]
# # 2. PERGUNTAS DO CEO DA HOUSE ROCKET

# %% [markdown]
# ## Quantas casas estão disponíveis para compra?
# ## Quantos atributos as casas possuem (número de quartos,m2, etc)?
# ## Quais são os atributos?
# ## Qual a casa mais cara do portfólio (casa com maior valor)?
# ## Qual a casa com o maior número de quartos?

# %% [markdown]
# ## 3. PLANEJAMENTO DAS RESPOSTAS
# ### 3.1 PLANEJAMENTO DO PRODUTO FINAL
# #### Pergunta: O que devo entregar (texto, planilha, e-mail, modelo de ML, dashboard)?
# #### Resposta: Será entregue um texto.
#
# #### Pergunta: Como será a entrega?
# #### Resposta: Perguntas | Respostas
#
#
# ### 3.2 PLANEJAMENTO DO PROCESSO
# #### Onde está a informação? https://github.com/vicdacos/Python_Data_Analysis/find/main![image.png](attachment:image.png);
# #### Como coletar a informação? Python;
# #### Responder às perguntas:
#
#     Quantas casas estão disponíveis para compras? Se cada linha do arquivo for uma casa, CONTAR LINHAS;
#
# 	Quantos atributos as casas possuem (número de quartos, número de garagens, m2, etc)? CONTAR COLUNAS;
#
# 	Quais são os atributos? NOMES DAS COLUNAS;
#
# 	Qual a casa mais cara do portfólio (casa com maior valor)? ORDERNAR o campo 'price' do MAIOR VALOR;
#
#     Qual a casa com o maior número de quartos? ORDERNAR o campo 'bedrooms' do MAIOR VALOR.

# %% [markdown]
# ### 4. CÓDIGOS

# %%
# importando o pacote PANDAS
import pandas as pd
# carregando o dataset
data = pd.read_csv ( r'C:\Users\victo\Desktop\House_Rocket\kc_house_data.csv' )
# explorando o dataset
# 5 primeiras linhas do dataset
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Quantidade de linhas e colunas do dataset
data.shape
# Out:
# (21613, 21)

# %%
# Nome das colunas
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Mostrar na tela o dataset ordenado pela coluna price
data[['id', 'price']].sort_values('price', ascending = False)
# Out:
#                id      price
# 7252   6762700020  7700000.0
# 3914   9808700762  7062500.0
# 9254   9208900037  6885000.0
# 4411   2470100110  5570000.0
# 1448   8907500070  5350000.0
# ...           ...        ...
# 8274   3883800011    82000.0
# 16198  3028200080    81000.0
# 465    8658300340    80000.0
# 15293    40000362    78000.0
# 1149   3421079032    75000.0
#
# [21613 rows x 2 columns]
